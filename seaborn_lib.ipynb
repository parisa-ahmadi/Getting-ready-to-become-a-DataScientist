# %% [markdown]
# <a href="https://colab.research.google.com/github/parisa-ahmadi/PythonBasics/blob/main/seaborn_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sb
import pandas as pd
import numpy as np

usa=pd.read_csv("usa.csv")
usa
# Out:
#           Grade  Year Category  Number Tested  Mean Scale Score  Level 1 #  \
# 0             3  2006    Asian           9768               700        243
# 1             4  2006    Asian           9973               699        294
# 2             5  2006    Asian           9852               691        369
# 3             6  2006    Asian           9606               682        452
# 4             7  2006    Asian           9433               671        521
# ..          ...   ...      ...            ...               ...        ...
# 163           5  2011    White          10808               699        311
# 164           6  2011    White           9875               695        409
# 165           7  2011    White           9679               690        423
# 166           8  2011    White           9570               688        433
# 167  All Grades  2011    White          62193               695       2418
#
# ...

# %%
usa.isnull().sum()
# Out:
# Grade               0
# Year                0
# Category            0
# Number Tested       0
# Mean Scale Score    0
# Level 1 #           0
# Level 1 %           0
# Level 2 #           0
# Level 2 %           0
# Level 3 #           0
# Level 3 %           0
# Level 4 #           0
# Level 4 %           0
# Level 3+4 #         0
# Level 3+4 %         0
# dtype: int64

# %%
sb.lineplot(data=usa)
# Out:
# <AxesSubplot:>

# %%
datum=pd.read_csv("data.csv")
datum
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
datum.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
sb.lineplot(data=datum)
# Out:
# <AxesSubplot:>
