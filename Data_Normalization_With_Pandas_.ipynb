# %% [markdown]
# <a href="https://colab.research.google.com/github/parisa-ahmadi/PythonBasics/blob/main/Data_Normalization_With_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code By Parisan.Ahmadi
import pandas as pd
import seaborn as sb
df=pd.read_csv("data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
sb.lmplot(x="Calories" , y="Maxpulse", data=df)

# %%
#simple feature scaling(Normalization)
df["Calories"]=df["Calories"]/df["Calories"].max()
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110  0.706522  0.198221
# 1          60    117  0.788043  0.236838
# 2          60    103  0.733696  0.160046
# 3          45    109  0.951087  0.128225
# 4          45    117  0.804348  0.196508
# ..        ...    ...       ...       ...
# 164        60    105  0.760870  0.132866
# 165        60    110  0.788043  0.137948
# 166        60    115  0.788043  0.143583
# 167        75    120  0.815217  0.149218
# 168        75    125  0.815217  0.154743
#
# [169 rows x 4 columns]

# %%
#Xnew=Xold/Xmax
df["Maxpulse"]=df["Maxpulse"]/df["Maxpulse"].max()
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110  0.706522  0.198221
# 1          60    117  0.788043  0.236838
# 2          60    103  0.733696  0.160046
# 3          45    109  0.951087  0.128225
# 4          45    117  0.804348  0.196508
# ..        ...    ...       ...       ...
# 164        60    105  0.760870  0.132866
# 165        60    110  0.788043  0.137948
# 166        60    115  0.788043  0.143583
# 167        75    120  0.815217  0.149218
# 168        75    125  0.815217  0.154743
#
# [169 rows x 4 columns]

# %%
#Max-Min(Normalization)
#Xnew=Xold - Xmin / Xmax - Xmin
df["Calories"]=(df["Calories"]-df["Calories"].min())/(df["Calories"].max()-df["Calories"].min())
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110  0.706522  0.198221
# 1          60    117  0.788043  0.236838
# 2          60    103  0.733696  0.160046
# 3          45    109  0.951087  0.128225
# 4          45    117  0.804348  0.196508
# ..        ...    ...       ...       ...
# 164        60    105  0.760870  0.132866
# 165        60    110  0.788043  0.137948
# 166        60    115  0.788043  0.143583
# 167        75    120  0.815217  0.149218
# 168        75    125  0.815217  0.154743
#
# [169 rows x 4 columns]

# %%
#Z-score(Normalization)
#Xnew=Xold - M(Meo or mean) / Standard Division(Std)
df["Calories"]=(df["Calories"] - df["Calories"].mean())/df["Calories"].std()
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110  0.706522  0.125046
# 1          60    117  0.788043  0.387453
# 2          60    103  0.733696 -0.134358
# 3          45    109  0.951087 -0.350590
# 4          45    117  0.804348  0.113409
# 5          60    102  0.690217 -0.284519
# 6          60    110  0.739130 -0.006721
# 7          45    104  0.728261 -0.459833
# 8          30    109  0.722826 -0.678318
# 9          60     98  0.673913 -0.400894
# 10         60    103  0.798913 -0.174526
# 11         60    100  0.652174 -0.469593
# 12         60    106  0.695652 -0.114461
# 13         60    104  0.717391  0.013176
# 14         60     98  0.668478 -0.378370
# 15         60     98  0.652174 -0.602862
# 16         60    100  0.652174 -0.284519
# 17         45     90  0.608696       NaN
# 18         60    103  0.668478 -0.198177
# 19         45     97  0.679348 -0.498499
# 20         60    108  0.711957 -0.043510
# 21         45    100  0.646739 -0.352092
# ...
